# %% [markdown]
# ## 💡 Final Conclusion
#
# - Customers on short-term contracts are more likely to churn
# - Higher monthly charges increase churn probability
# - Retention strategies should focus on pricing and contract plans

# %% [markdown]
# ### 🔍 Insight:
# - Month-to-month contracts show higher churn
# - Long-term contracts reduce churn significantly

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ### 🔍 Insight:
# - Customers with higher monthly charges tend to churn more
# - Pricing strategy may impact customer retention

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title("Monthly Charges vs Churn")
plt.show()

# %% [markdown]
# ### 🔍 Insight:
# - Majority of customers are retained
# - A noticeable number of customers are churning
# - Indicates need for customer retention strategies

# %%
df.to_csv('../data/raw/churn.csv', index=False)

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

n = 1000

df = pd.DataFrame({
    'customerID': ['CUST' + str(i) for i in range(n)],
    'gender': np.random.choice(['Male', 'Female'], n),
    'SeniorCitizen': np.random.choice([0, 1], n),
    'tenure': np.random.randint(1, 72, n),
    'MonthlyCharges': np.random.uniform(20, 120, n),
    'TotalCharges': np.random.uniform(100, 8000, n),
    'Contract': np.random.choice(['Month-to-month', 'One year', 'Two year'], n),
    'InternetService': np.random.choice(['DSL', 'Fiber optic', 'No'], n),
    'Churn': np.random.choice(['Yes', 'No'], n)
})

df.head()
# Out:
#   customerID  gender  SeniorCitizen  tenure  MonthlyCharges  TotalCharges  \
# 0      CUST0    Male              1      47       94.171206    850.919060
# 1      CUST1  Female              0      12      108.145078   6631.299467
# 2      CUST2    Male              0      62       47.790210    476.365934
# 3      CUST3    Male              0       8       39.395387   5841.318871
# 4      CUST4    Male              0      21      107.981649   6213.859152
#
#          Contract InternetService Churn
# 0  Month-to-month              No   Yes
# 1  Month-to-month             DSL    No
# 2        Two year             DSL    No
# 3        One year              No   Yes
# 4        One year             DSL   Yes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Churn', data=df)
plt.title("Churn Distribution")
plt.show()

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# # 📊 Customer Churn Analysis
# This project analyzes customer churn behavior and provides insights.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
